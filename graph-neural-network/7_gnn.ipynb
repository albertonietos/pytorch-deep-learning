# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Number of points for this notebook:</b> 4
# <br>
# <b>Deadline:</b> April 20, 2020 (Monday). 23:00
# </div>
#
# # Exercise 7. Graph neural networks. Recurrent relational network
#
# The goal of this exercise is to get familiar with graph neural networks.
#
# We will implement a simplified version of the recurrent relational network proposed in [this paper](http://papers.nips.cc/paper/7597-recurrent-relational-networks.pdf).

# %%
skip_training = False  # Set this flag to True before validation and submission

# %%
# During evaluation, this cell sets skip_training to True
# skip_training = True

# %%
import time
import torch
import numpy as np
import matplotlib.pyplot as plt

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import tools
import tests

# %%
# When running on your own computer, you can specify the data directory by:
# data_dir = tools.select_data_dir('/your/local/data/directory')
data_dir = tools.select_data_dir()
# Out:
# The data directory is ../data

# %%
# Select the device for training (use GPU if you have one)
# device = torch.device('cuda:0')
device = torch.device('cpu')

# %%
if skip_training:
    # The models are always evaluated on CPU
    device = torch.device("cpu")

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce GTX 950M'

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Data
#
# The dataset is a set of sudoku puzzles with solutions obtained from [here](https://github.com/locuslab/SATNet).

# %%
import data
trainset = data.Sudoku(data_dir, train=True)
testset = data.Sudoku(data_dir, train=False)

x, y = trainset[0]
print(x.shape, y.shape)
# Out:
# torch.Size([81, 9]) torch.Size([81])

# %%
x[0,:]
# This is the one-hot encoded version of the input
# x is made of 81 rows (one for every cell in the sudok) and 9 values of the one-hot encoding
# The position of the nonzero value indicates which integer is in that cell
# Out:
# tensor([0., 0., 0., 0., 0., 1., 0., 0., 0.])

# %% [markdown]
# We can visualize the data in the following way.

# %%
def sudoku_to_labels(x):
    """Convert one-hot coded sudoku puzzles to labels. -1 corresponds to missing labels.
    
    Args:
      x of shape (n_rows=9, n_colums=9, n_digits=9): Tensor with a sudoku board. The digits are one-hot coded.
                  Cells with unknown digits have all zeros along the third dimension.
    """
    assert x.shape == torch.Size([9, 9, 9]), "Wrong shape {}".format(x.shape)
    is_filled = x.sum(dim=2)
    y = x.argmax(dim=2)
    y[~is_filled.bool()] = -1
    return y

# %%
sudoku_to_labels(x.view(9, 9, 9)).shape
# The one-hot encoding is transformed to integers where each value is in their respective cell.
# Out:
# torch.Size([9, 9])

# %%
print(sudoku_to_labels(x.view(9, 9, 9)))
# Out:
# tensor([[ 5,  6, -1, -1, -1, -1, -1, -1,  4],
#         [-1, -1,  2, -1,  3, -1, -1,  7,  1],
#         [-1,  3, -1, -1, -1,  4,  0,  2,  5],
#         [-1, -1, -1,  6,  2, -1, -1,  8, -1],
#         [ 2, -1,  3,  1, -1,  5, -1,  6, -1],
#         [-1, -1,  0, -1,  8, -1,  5, -1, -1],
#         [ 4, -1,  8, -1, -1,  7, -1, -1, -1],
#         [-1, -1, -1,  8,  4, -1,  1, -1,  7],
#         [-1, -1, -1,  0,  1,  6,  3, -1, -1]])

# %%
tools.draw_sudoku(x.view(9, 9, 9), logits=False)

# %% [markdown]
# ## Graph
#
# We describe each sudoku puzzle as a graph in which each node corresponds to one of the 9*9=81 cells in the puzzle. Each node is connected to 8+8+8-4=20 other nodes:
# * 8 nodes that correspond to other cells in the same row
# * 8 nodes that correspond to other cells in the same column
# * 8 nodes that correspond to other cells in the same $3\times 3$ box
# * 4 cells appear both in a $3\times 3$ box and in the same row or column.
#
# In this exercise, we decribe a graph as a set of edges. Each edge is a pair (`src_id`, `dst_id`) where `src_id` is the id of the source node and `dst_id` is the id of the destination node. In the cell below, your task is to describe such a graph by producing two lists:
# * a list of source node ids `src_id` of all edges
# * a list of destination node ids `dst_id` of all edges
#
# Note: Our tests assume that node ids are between 0 and 80. Please follow this convention.

# %%
def sudoku_edges():
    """Generate edges of the graph describing the sudoku puzzle.
    
    Returns:
      src_ids: LongTensor of length 1620 with source node ids of all the edges in the graph.
      dst_ids: LongTensor of length 1620 with destination node ids of all the edges in the graph
    
    Note: Our tests assume that node ids are between 0 and 80. Please follow this convention.
    """
    # YOUR CODE HERE
    def cross(array):
        """
        Method that generates all the possible edges (i.e. connections) between the given nodes (i.e. cells).
        """
        return [(i,j) for i in array.flatten() for j in array.flatten() if not i==j]
    
    # Initialize array containing all existing nodes (size 81, 9x9) and reshape it to Sudoku size
    idx = np.arange(81).reshape(9, 9)
    
    row_edges, col_edges, box_edges = [], [], []
    max_flat_length = 9
    for i in range(max_flat_length):
        # Get the edges for the i-th row and column
        row_edges += cross(idx[i,:])
        col_edges += cross(idx[:,i])
        
    max_box_length = 3
    for i in range(max_box_length):
        for j in range(max_box_length):
            box_edges += cross(idx[3*i:3*(i+1), 3*j:3*(j+1)])

    edges = list(set(row_edges+col_edges+box_edges))
    src_ids = [edge[0] for edge in edges]
    dst_ids = [edge[1] for edge in edges]
    
    src_ids = torch.LongTensor(src_ids)
    dst_ids = torch.LongTensor(dst_ids)
    
    return src_ids, dst_ids

# %%
sudoku_src_ids, sudoku_dst_ids = sudoku_edges()
print('Number of edges in each sudoku graph: %d' % len(sudoku_src_ids))
assert sudoku_src_ids.dtype == torch.long and sudoku_dst_ids.dtype == torch.long
assert len(sudoku_src_ids) == len(sudoku_dst_ids), "The number of source and destination nodes should be same."
assert len(sudoku_src_ids) == 1620, "Wrong number of edges ({}), expected: 1620".format(len(sudoku_src_ids))
assert min(sudoku_src_ids) == 0 and max(sudoku_src_ids) == 80, "Node ids should be between 0 and 80"
assert min(sudoku_dst_ids) == 0 and max(sudoku_dst_ids) == 80, "Node ids should be between 0 and 80"
# Out:
# Number of edges in each sudoku graph: 1620

# %% [markdown]
# ## Custom data loader
#
# We first create a custom data loader to process a mini-batch of graphs (in parallel) to compute the derivatives wrt the parameters of the graph neural network. To do that, **we transform a mini-batch of graphs to one large graph without interconnecting edges between the subgraphs corresponding to individual examples in the mini-batch.** We do this using a custom collate function that you need to implement in the cell below.

# %%
def collate(list_of_samples):
    """Merges a list of samples to form a mini-batch.

    Args:
      list_of_samples is a list of tuples (inputs, targets),
          inputs of shape (n_nodes, 9): Inputs to each node in the graph. Inputs are one-hot coded digits
              in the sudoku puzzle. A missing digit is encoded with all zeros. n_nodes=81 for the sudoku graph.
          targets of shape (n_nodes): A LongTensor of targets (correct digits in the sudoku puzzle).

    Returns:
      inputs of shape (batch_size*n_nodes, 9): Inputs to each node in the graph. Inputs are one-hot coded digits
          in the sudoku puzzle. A missing digit is encoded with all zeros. n_nodes=81 for the sudoku graph.
      targets of shape (batch_size*n_nodes): A LongTensor of targets (correct digits in the sudoku puzzle).
      src_ids of shape (batch_size*1620): LongTensor of source node ids for each edge in the large graph.
          The source ids should be between 0 and batch_size * 81.
      dst_ids of shape (batch_size*1620): LongTensor of destination node ids for each edge in the large graph.
          The destination ids should be between 0 and batch_size * 81.
    """
    # YOUR CODE HERE
    batch_size = len(list_of_samples)
    n_nodes = len(list_of_samples[0][0])

    inputs = torch.zeros((batch_size*n_nodes, 9))
    targets = torch.zeros((batch_size*n_nodes))
    src_ids = torch.zeros((batch_size*1620))
    dst_ids = torch.zeros((batch_size*1620))
    
    src_id, dst_id = sudoku_edges()
    
    j = 0
    k = 0
    for i in range(batch_size):
        inputs[j:(j+n_nodes),:] = list_of_samples[i][0]
        targets[j:(j+n_nodes)] = list_of_samples[i][1]
        src_ids[k:(k+1620)], dst_ids[k:(k+1620)] = src_id, dst_id
        src_id += 81
        dst_id += 81
        j += n_nodes
        k += 1620
    
    # Transform to LongTensor
    targets = targets.type(torch.LongTensor)
    src_ids = src_ids.type(torch.LongTensor)
    dst_ids = dst_ids.type(torch.LongTensor)
    
    return inputs, targets, src_ids, dst_ids

# %%
batch_size = 2
n_nodes = 81
inputs, targets, src_ids, dst_ids = collate([trainset[0], trainset[1]])
inputs.dtype, src_ids.dtype
# Out:
# (torch.float32, torch.int64)

# %%
def test_collate_shapes():
    batch_size = 2
    n_nodes = 81
    inputs, targets, src_ids, dst_ids = collate([trainset[0], trainset[1]])
    assert inputs.shape == torch.Size([batch_size*n_nodes, 9]), f"Bad inputs.shape: {inputs.shape}"
    assert targets.shape == torch.Size([batch_size*n_nodes]), f"Bad targets.shape: {targets.shape}"
    assert src_ids.shape == torch.Size([batch_size*1620]), f"Bad src_ids.shape: {src_ids.shape}"
    assert dst_ids.shape == torch.Size([batch_size*1620]), f"Bad dst_ids.shape: {dst_ids.shape}"
    assert min(src_ids) == 0 and max(src_ids) == batch_size*81-1
    assert min(dst_ids) == 0 and max(dst_ids) == batch_size*81-1
    print('Success')

test_collate_shapes()
# Out:
# Success

# %%
trainloader = DataLoader(trainset, batch_size=16, collate_fn=collate)
testloader = DataLoader(testset, batch_size=16, collate_fn=collate)

# %% [markdown]
# <img src="recurrent_rn.png" width=300 style="float: right;">
#
# # Graph neural network
#
# You need to implement a graph neural network in the cell below. Its forward function consists of `n_iters` iterations with the following steps:
# * For each node, compute the messages from all its neighbors using the message network (see description below).
# * For each destination node, aggregate (by summation) all the messages sent by its neighbors. You may find it useful to use function [`index_add_`](https://pytorch.org/docs/stable/tensors.html#torch.Tensor.index_add_) for that.
# * The aggregated messages are concatenated with the node inputs to form the inputs of the gated recurrent units (GRUs) whose states represent the states of the nodes. The node inputs are one-hot coded digits 1-9 of the sudoku puzzle, a missing digit is encoded with all zeros.
# * The states of the GRUs are updated using the standard GRU computations.
# * The states of each graph node are linearly combined to compute the output of the corresponding node at the current iteration.
#
# **Note that since we combine all graphs in the mini-batch into a single graph using `collate()` function, we do not need to care about batches in our implementation of GNN.**
#
#
# ### Message network
#
# * All messages are computed with the same message network (shared parameters).
# * The message network takes as inputs the states of the source node and the states of the destination node and produces a vector with `n_edge_features`.
# * We used as the message network a multilayer perceptron (MLP) network with the following architecture:
#   * hidden layer with 96 neurons and ReLU nonlinearity
#   * hidden layer with 96 neurons and ReLU nonlinearity
#   * output layer with `n_edge_features` output features.
# * **Important:** Our tests assume that the message network is defined as an attribute called `msg_net`, that is it can be accessed as follows:
# ```
# gnn = GNN()
# print(gnn.msg_net)
# ```
#
# ### Notes
#
# * Please initialize the node states (before the first iteration) with all zeros.
# * The messages computed in the first iteration are not informative because they combine zero states.

# %%
class GNN(nn.Module):
    def __init__(self, n_iters=7, n_node_features=10, n_node_inputs=9, n_edge_features=11, n_node_outputs=9):
        """
        Args:
          n_iters: Number of graph iterations.
          n_node_features: Number of features in the states of each node.
          n_node_inputs: Number of inputs to each graph node (on each graph iteration).
          n_edge_features: Number of features in the messages sent along the edges of the graph (produced
              by the message network).
          n_node_outputs: Number of outputs produced by at each node of the graph.
        """
        super(GNN, self).__init__()
        
        self.n_iters = n_iters
        self.n_node_features = n_node_features
        self.n_node_inputs = n_node_inputs
        self.n_edge_features = n_edge_features
        self.n_node_outputs = n_node_outputs
        
        # YOUR CODE HERE
        self.msg_net = nn.Sequential(nn.Linear(n_node_features*2, 96), nn.ReLU(),
                                     nn.Linear(96, 96), nn.ReLU(),
                                     nn.Linear(96, n_edge_features))
        self.gru = nn.GRU(input_size=n_node_inputs+n_edge_features, hidden_size=n_node_features)
        self.feedforward = nn.Linear(in_features=n_node_features, out_features=n_node_outputs)

    def forward(self, node_inputs, src_ids, dst_ids):
        """
        Args:
          node_inputs of shape (n_nodes, n_node_inputs): Tensor of inputs to every node of the graph.
          src_ids of shape (n_edges): Indices of source nodes of every edge.
          dst_ids of shape (n_edges): Indices of destination nodes of every edge.
          
        Returns:
          outputs of shape (n_iters, n_nodes, n_node_outputs): Outputs of all the nodes at every iteration of the
              graph neural network.
        """
        # YOUR CODE HERE
        n_edges = src_ids.size()[0] # 1620
        n_nodes = node_inputs.size(0) # 81
        nodes_states = torch.zeros(n_nodes, self.n_node_features) # [81, 10]
        outputs = torch.zeros(self.n_iters, n_nodes, self.n_node_outputs) # [7, 81, 9] n_node_outputs is one-hot encoded
        
#         print("n_edges", n_edges)
        
        for i in range(self.n_iters):
#             print(f"Iteration {i}")
            messages = torch.zeros(n_nodes, self.n_edge_features, device=node_inputs.device)

            hidden_src_node = nodes_states[src_ids] # hidden state of the source nodes, shape [n_edges, n_node_features] = [1620, 10]
            hidden_dst_node = nodes_states[dst_ids] # hidden state of the destination nodes, shape [n_edges, n_node_features] = [1620, 10]
#             print("hidden_src_input.size()", hidden_src_node.size())
#             print("hidden_dst_node.size()", hidden_dst_node.size())
            msg_net_inputs = torch.cat((hidden_src_node, hidden_dst_node), dim=-1) # shape [n_edges, n_node_features*2]=[1620, 20]
#             print("msg_net_inputs.size()", msg_net_inputs.size())
            
            messages_edges = self.msg_net(msg_net_inputs) # shape [n_edges, n_edge_features]=[1620,11]
            
#             print("messages.size():", messages.size())
            messages_nodes = torch.zeros((n_nodes, self.n_edge_features)) # [n_nodes, n_edge_features]=[81, 11]
            # Aggregate messages for each node
            messages_nodes = messages_nodes.index_add_(0, dst_ids, messages_edges)
#             print("messages_nodes.size()", messages_nodes.size())
            
            # Updata the node hidden state
#             print("node_inputs.size()", node_inputs.size())
            gru_input = torch.cat((messages_nodes, node_inputs), dim=1) # shape [n_nodes, n_node_inputs+n_edge_features]=[81,20]
            gru_input = gru_input.unsqueeze(0) # insert seq_len dimension shae [1, 81, 20]
#             print("gru_input.size()", gru_input.size())
            
#             print("nodes_states.unsqueeze(0).size()", nodes_states.unsqueeze(0).size())
            ouput, nodes_states = self.gru(gru_input, nodes_states.unsqueeze(0))
            
            # Squeeze nodes hidden state to fit with previous dimension
            nodes_states = nodes_states.squeeze()
            # Compute the output of each node in this iteration
            outputs[i,:,:] = self.feedforward(nodes_states)
        return outputs

# %%
# Shape tests of the message network
def test_GNN_msg_net():
    src_ids, dst_ids = sudoku_edges()
    src_ids, dst_ids = torch.LongTensor(src_ids), torch.LongTensor(dst_ids)
    n_nodes = 81
    n_edges = len(src_ids)
    n_node_features = 5
    n_edge_features = 6

    gnn = GNN(n_iters=7, n_node_features=n_node_features, n_edge_features=n_edge_features)
    msg_net_inputs = torch.zeros(n_edges, 2*n_node_features)
    assert hasattr(gnn, 'msg_net'), "Cannot find the message network."
    messages = gnn.msg_net(msg_net_inputs)  # [n_edges, n_edge_features]
    assert messages.shape == torch.Size([n_edges, n_edge_features]), f"Bad messages.shape: {messages.shape}"
    print('Success')

test_GNN_msg_net()
# Out:
# Success

# %%
# Shape tests
def test_GNN_shape():
    src_ids, dst_ids = sudoku_edges()
    src_ids, dst_ids = torch.LongTensor(src_ids), torch.LongTensor(dst_ids)
    n_nodes = 81

    gnn = GNN(n_iters=7)
    node_inputs = torch.zeros([n_nodes, 9])
    outputs = gnn(node_inputs, src_ids, dst_ids)  # [n_iters, batch*n_nodes, 9]
    assert outputs.shape == torch.Size([gnn.n_iters, n_nodes, 9]), f"Bad outputs.shape: {outputs.shape}"
    print('Success')

test_GNN_shape()
# Out:
# Success

# %%
# Test of the forward function
tests.test_GNN_forward(GNN)
# Out:
# outputs:
#  tensor([[[ 0.0000,  0.0498],
#          [ 0.0000,  0.2311],
#          [ 0.0000,  0.3581]],
#
#         [[-0.0012,  0.0736],
#          [-0.0058,  0.3434],
#          [-0.0089,  0.5360]]])
# expected:
#  tensor([[[ 0.0000,  0.0498],
#          [ 0.0000,  0.2311],
#          [ 0.0000,  0.3581]],
#
#         [[-0.0012,  0.0736],
#          [-0.0058,  0.3434],
#          [-0.0089,  0.5360]]])
# Success

# %% [markdown]
# ## Train the network

# %% [markdown]
# ### Training loop
#
# Your task is to implement the training loop. The recommended hyperparameters:
# * Adam optimizer with learning rate 0.001
# * 30 epochs is usually enough for training to converge.
# * The loss should be the mean of the classification losses computed at **every** GNN iteration. This way you encourage the GNN to find the correct solution with as few iterations as possible.
#
# Hints:
# * The training loss at convergence can reach 0.25. The classification loss computed after the **last** GNN iteration should be close to 0.
# * The fraction of solved test puzzles is usually close to 1 (we will use the threshold of 0.93 in the tests).
# * We recommend you to track the fraction of solved puzzles in the test set using the function below.

# %%
# Create network
gnn = GNN()
gnn.to(device)
# Out:
# GNN(
#   (msg_net): Sequential(
#     (0): Linear(in_features=20, out_features=96, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=96, out_features=96, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=96, out_features=11, bias=True)
#   )
#   (gru): GRU(20, 10)
#   (feedforward): Linear(in_features=10, out_features=9, bias=True)
# )

# %%
def fraction_of_solved_puzzles(gnn, testloader):
    with torch.no_grad():
        n_test = 0
        n_test_solved = 0
        for i, (inputs, targets, src_ids, dst_ids) in enumerate(testloader):
            # inputs is [n_nodes, 9*9, 9]
            # targets is [n_nodes]
            batch_size = inputs.size(0) // 81
            inputs, targets = inputs.to(device), targets.to(device)
            src_ids, dst_ids = src_ids.to(device), dst_ids.to(device)

            outputs = gnn(inputs, src_ids, dst_ids)  # [n_iters, batch*n_nodes, 9]
            solution = outputs.view(gnn.n_iters, batch_size, 9, 9, 9)

            final_solution = solution[-1].argmax(dim=3)
            solved = (final_solution.view(-1, 81) == targets.view(batch_size, 81)).all(dim=1)
            n_test += solved.size(0)
            n_test_solved += solved.sum().item()
            return n_test_solved / n_test

# %%
# Implement the training loop here
if not skip_training:
    # YOUR CODE HERE
    n_epochs = 30
    iters = 1
    optimizer = optim.Adam(gnn.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(reduction='mean')
    train_loss, test_lst = [], []
    for e in range(n_epochs):
        print(f"Epoch {e}")
        for batch in trainloader:
            inputs, targets, src_ids, dst_ids = batch
            inputs, targets = inputs.to(device), targets.to(device)
            src_ids, dst_ids = src_ids.to(device), dst_ids.to(device)
            
            optimizer.zero_grad()
            
#             print("inputs.size()", inputs.size())
#             print("src_ids.size()", src_ids.size())
#             print("dst_ids.size()", dst_ids.size())
            outputs = gnn(inputs, src_ids, dst_ids)
#             print("outputs[i,:,:].size()", outputs[0,:,:].size())
#             print("outputs[i,:,:].dtype", outputs[0,:,:].dtype)
#             print("outputs[0,0,:]", outputs[0,0,:])

            loss = 0
#             print("targets.size()", targets.size())
#             print("targets.dtype", targets.dtype)
#             print("targets[0]", targets[0])
            for i in range(gnn.n_iters):
                loss += criterion(outputs[i,:,:], targets)
            loss /= gnn.n_iters
            
            
            
            loss.backward()
            optimizer.step()
            
            iters += 1
            train_loss.append(loss.item())
            if iters % 5 == 0:
                test_metric = fraction_of_solved_puzzles(gnn, testloader)
                test_lst.append(test_metric)
                print(f"Iteration {iters}")
                print(f"Loss: {loss.item()}, solved sudokus {test_metric}")
        plt.plot(train_loss)
# Out:
# Epoch 0
# Iteration 5
# Loss: 1.9219141006469727, solved sudokus 0.0
# Iteration 10
# Loss: 1.9250997304916382, solved sudokus 0.0
# Iteration 15
# Loss: 1.9156349897384644, solved sudokus 0.0
# Iteration 20
# Loss: 1.8780955076217651, solved sudokus 0.0
# Iteration 25
# Loss: 1.8555265665054321, solved sudokus 0.0
# Iteration 30
# Loss: 1.8218355178833008, solved sudokus 0.0
# Iteration 35
# Loss: 1.804538607597351, solved sudokus 0.0
# Iteration 40
# Loss: 1.7855666875839233, solved sudokus 0.0
# Iteration 45
# Loss: 1.7716752290725708, solved sudokus 0.0
# Iteration 50
# Loss: 1.7383155822753906, solved sudokus 0.0
# Iteration 55
# Loss: 1.727289080619812, solved sudokus 0.0
# Iteration 60
# Loss: 1.7029590606689453, solved sudokus 0.0
# Iteration 65
# Loss: 1.6972143650054932, solved sudokus 0.0
# Iteration 70
# Loss: 1.6851435899734497, solved sudokus 0.0
# Iteration 75
# Loss: 1.6833016872406006, solved sudokus 0.0
# Iteration 80
# Loss: 1.6700036525726318, solved sudokus 0.0
# Iteration 85
# Loss: 1.6474124193191528, solved sudokus 0.0
# Iteration 90
# Loss: 1.6673868894577026, solved sudokus 0.0
# Iteration 95
# Loss: 1.637054681777954, solved sudokus 0.0
# Iteration 100
# Loss: 1.6169183254241943, solved sudokus 0.0
# Iteration 105
# Loss: 1.6341264247894287, solved sudokus 0.0
# Iteration 110
# Loss: 1.5882594585418701, solved sudokus 0.0
# Iteration 115
# Loss: 1.6050007343292236, solved sudokus 0.0
# Iteration 120
# Loss: 1.5937169790267944, solved sudokus 0.0
# Iteration 125
# Loss: 1.5746831893920898, solved sudokus 0.0
# Iteration 130
# Loss: 1.565872311592102, solved sudokus 0.0
# Iteration 135
# Loss: 1.5197511911392212, solved sudokus 0.0
# Iteration 140
# Loss: 1.5437382459640503, solved sudokus 0.0
# Iteration 145
# Loss: 1.5413367748260498, solved sudokus 0.0
# Iteration 150
# Loss: 1.5286720991134644, solved sudokus 0.0
# Iteration 155
# Loss: 1.505829095840454, solved sudokus 0.0
# Iteration 160
# Loss: 1.4787534475326538, solved sudokus 0.0
# Iteration 165
# Loss: 1.4709047079086304, solved sudokus 0.0
# Iteration 170
# Loss: 1.4882375001907349, solved sudokus 0.0
# Iteration 175
# Loss: 1.5036362409591675, solved sudokus 0.0
# Iteration 180
# Loss: 1.4423878192901611, solved sudokus 0.0
# Iteration 185
# Loss: 1.4488108158111572, solved sudokus 0.0
# Iteration 190
# Loss: 1.4732705354690552, solved sudokus 0.0
# Iteration 195
# Loss: 1.4376341104507446, solved sudokus 0.0
# Iteration 200
# Loss: 1.4353755712509155, solved sudokus 0.0
# Iteration 205
# Loss: 1.4136830568313599, solved sudokus 0.0
# Iteration 210
# Loss: 1.4084358215332031, solved sudokus 0.0
# Iteration 215
# Loss: 1.4052250385284424, solved sudokus 0.0
# Iteration 220
# Loss: 1.3949652910232544, solved sudokus 0.0
# Iteration 225
# Loss: 1.3722933530807495, solved sudokus 0.0
# Iteration 230
# Loss: 1.3789957761764526, solved sudokus 0.0
# Iteration 235
# Loss: 1.3465837240219116, solved sudokus 0.0
# Iteration 240
# Loss: 1.3661812543869019, solved sudokus 0.0
# Iteration 245
# Loss: 1.3395917415618896, solved sudokus 0.0
# Iteration 250
# Loss: 1.3449039459228516, solved sudokus 0.0
# Iteration 255
# Loss: 1.3267227411270142, solved sudokus 0.0
# Iteration 260
# Loss: 1.3171366453170776, solved sudokus 0.0
# Iteration 265
# Loss: 1.3120002746582031, solved sudokus 0.0
# Iteration 270
# Loss: 1.2956829071044922, solved sudokus 0.0
# Iteration 275
# Loss: 1.3103320598602295, solved sudokus 0.0
# Iteration 280
# Loss: 1.2776920795440674, solved sudokus 0.0
# Iteration 285
# Loss: 1.280187964439392, solved sudokus 0.0
# Iteration 290
# Loss: 1.2596067190170288, solved sudokus 0.0
# Iteration 295
# Loss: 1.2368451356887817, solved sudokus 0.0
# Iteration 300
# Loss: 1.2790510654449463, solved sudokus 0.0
# Iteration 305
# Loss: 1.2658684253692627, solved sudokus 0.0
# Iteration 310
# Loss: 1.2390451431274414, solved sudokus 0.0
# Iteration 315
# Loss: 1.207283854484558, solved sudokus 0.0
# Iteration 320
# Loss: 1.231223464012146, solved sudokus 0.0
# Iteration 325
# Loss: 1.2098615169525146, solved sudokus 0.0
# Iteration 330
# Loss: 1.1737796068191528, solved sudokus 0.0
# Iteration 335
# Loss: 1.216171145439148, solved sudokus 0.0
# Iteration 340
# Loss: 1.1964561939239502, solved sudokus 0.0
# Iteration 345
# Loss: 1.2167586088180542, solved sudokus 0.0
# Iteration 350
# Loss: 1.198879599571228, solved sudokus 0.0
# Iteration 355
# Loss: 1.144206166267395, solved sudokus 0.0
# Iteration 360
# Loss: 1.1636189222335815, solved sudokus 0.0
# Iteration 365
# Loss: 1.139833927154541, solved sudokus 0.0
# Iteration 370
# Loss: 1.0971394777297974, solved sudokus 0.0
# Iteration 375
# Loss: 1.1104800701141357, solved sudokus 0.0
# Iteration 380
# Loss: 1.0835644006729126, solved sudokus 0.0
# Iteration 385
# Loss: 1.1087100505828857, solved sudokus 0.0
# Iteration 390
# Loss: 1.1069525480270386, solved sudokus 0.0
# Iteration 395
# Loss: 1.0681519508361816, solved sudokus 0.0
# Iteration 400
# Loss: 1.0850088596343994, solved sudokus 0.0
# Iteration 405
# Loss: 1.0667250156402588, solved sudokus 0.0
# Iteration 410
# Loss: 1.059087872505188, solved sudokus 0.0
# Iteration 415
# Loss: 1.0678460597991943, solved sudokus 0.0
# Iteration 420
# Loss: 1.08538019657135, solved sudokus 0.0
# Iteration 425
# Loss: 1.062906265258789, solved sudokus 0.0
# Iteration 430
# Loss: 1.054423451423645, solved sudokus 0.0
# Iteration 435
# Loss: 1.0829687118530273, solved sudokus 0.0
# Iteration 440
# Loss: 1.0400052070617676, solved sudokus 0.0
# Iteration 445
# Loss: 1.0260707139968872, solved sudokus 0.0
# Iteration 450
# Loss: 1.0209944248199463, solved sudokus 0.0
# Iteration 455
# Loss: 1.0395509004592896, solved sudokus 0.0
# Iteration 460
# Loss: 0.9984199404716492, solved sudokus 0.0
# Iteration 465
# Loss: 1.015841007232666, solved sudokus 0.0
# Iteration 470
# Loss: 0.9953503608703613, solved sudokus 0.0
# Iteration 475
# Loss: 0.9965015053749084, solved sudokus 0.0
# Iteration 480
# Loss: 0.9551375508308411, solved sudokus 0.0
# Iteration 485
# Loss: 0.9913853406906128, solved sudokus 0.0
# Iteration 490
# Loss: 0.9541687965393066, solved sudokus 0.0
# Iteration 495
# Loss: 0.9680373072624207, solved sudokus 0.0
# Iteration 500
# Loss: 0.9472952485084534, solved sudokus 0.0
# Iteration 505
# Loss: 0.9385348558425903, solved sudokus 0.0
# Iteration 510
# Loss: 0.9131695628166199, solved sudokus 0.0
# Iteration 515
# Loss: 0.9448155760765076, solved sudokus 0.0
# Iteration 520
# Loss: 0.969028890132904, solved sudokus 0.0
# Iteration 525
# Loss: 0.9146753549575806, solved sudokus 0.0
# Iteration 530
# Loss: 0.9198682904243469, solved sudokus 0.0
# Iteration 535
# Loss: 0.9244372248649597, solved sudokus 0.0
# Iteration 540
# Loss: 0.888565182685852, solved sudokus 0.0
# Iteration 545
# Loss: 0.9220104217529297, solved sudokus 0.0
# Iteration 550
# Loss: 0.9092587232589722, solved sudokus 0.0
# Iteration 555
# Loss: 0.8856871724128723, solved sudokus 0.0
# Iteration 560
# Loss: 0.878463089466095, solved sudokus 0.0
# Epoch 1
# Iteration 565
# Loss: 0.8660921454429626, solved sudokus 0.0
# Iteration 570
# Loss: 0.8721915483474731, solved sudokus 0.0
# Iteration 575
# Loss: 0.8473700284957886, solved sudokus 0.0
# Iteration 580
# Loss: 0.8625770807266235, solved sudokus 0.0
# Iteration 585
# Loss: 0.8495749235153198, solved sudokus 0.0
# Iteration 590
# Loss: 0.8510976433753967, solved sudokus 0.0
# Iteration 595
# Loss: 0.8460969924926758, solved sudokus 0.0
# Iteration 600
# Loss: 0.8729166388511658, solved sudokus 0.0
# Iteration 605
# Loss: 0.8442711234092712, solved sudokus 0.0
# Iteration 610
# Loss: 0.8408777117729187, solved sudokus 0.0
# Iteration 615
# Loss: 0.8564141392707825, solved sudokus 0.0
# Iteration 620
# Loss: 0.8307773470878601, solved sudokus 0.0
# Iteration 625
# Loss: 0.8351431488990784, solved sudokus 0.0
# Iteration 630
# Loss: 0.841454803943634, solved sudokus 0.0
# Iteration 635
# Loss: 0.7909655570983887, solved sudokus 0.0
# Iteration 640
# Loss: 0.7665489912033081, solved sudokus 0.0
# Iteration 645
# Loss: 0.8159742951393127, solved sudokus 0.0
# Iteration 650
# Loss: 0.8401480317115784, solved sudokus 0.0
# Iteration 655
# Loss: 0.7981743216514587, solved sudokus 0.0
# Iteration 660
# Loss: 0.7864647507667542, solved sudokus 0.0
# Iteration 665
# Loss: 0.7565197348594666, solved sudokus 0.0
# Iteration 670
# Loss: 0.7559474110603333, solved sudokus 0.0
# Iteration 675
# Loss: 0.7749987244606018, solved sudokus 0.0
# Iteration 680
# Loss: 0.7814463973045349, solved sudokus 0.0
# Iteration 685
# Loss: 0.7383924722671509, solved sudokus 0.0
# Iteration 690
# Loss: 0.7477445006370544, solved sudokus 0.0
# Iteration 695
# Loss: 0.7530407309532166, solved sudokus 0.0
# Iteration 700
# Loss: 0.7355645895004272, solved sudokus 0.0
# Iteration 705
# Loss: 0.7117919325828552, solved sudokus 0.0
# Iteration 710
# Loss: 0.7231597304344177, solved sudokus 0.0
# Iteration 715
# Loss: 0.7440380454063416, solved sudokus 0.0
# Iteration 720
# Loss: 0.7074021697044373, solved sudokus 0.0
# Iteration 725
# Loss: 0.7461970448493958, solved sudokus 0.0
# Iteration 730
# Loss: 0.7229636907577515, solved sudokus 0.0
# Iteration 735
# Loss: 0.6726581454277039, solved sudokus 0.0
# Iteration 740
# Loss: 0.6717103719711304, solved sudokus 0.0
# Iteration 745
# Loss: 0.6803632378578186, solved sudokus 0.0
# Iteration 750
# Loss: 0.6702643632888794, solved sudokus 0.0
# Iteration 755
# Loss: 0.6810051202774048, solved sudokus 0.0
# Iteration 760
# Loss: 0.6642486453056335, solved sudokus 0.0
# Iteration 765
# Loss: 0.6700423359870911, solved sudokus 0.0
# Iteration 770
# Loss: 0.6448809504508972, solved sudokus 0.0
# Iteration 775
# Loss: 0.6382347941398621, solved sudokus 0.0
# Iteration 780
# Loss: 0.6211994886398315, solved sudokus 0.0
# Iteration 785
# Loss: 0.6444891095161438, solved sudokus 0.0
# Iteration 790
# Loss: 0.6485605239868164, solved sudokus 0.0
# Iteration 795
# Loss: 0.6642664670944214, solved sudokus 0.0
# Iteration 800
# Loss: 0.6581340432167053, solved sudokus 0.0
# Iteration 805
# Loss: 0.6879531145095825, solved sudokus 0.0
# Iteration 810
# Loss: 0.6824067831039429, solved sudokus 0.0
# Iteration 815
# Loss: 0.655265748500824, solved sudokus 0.0
# Iteration 820
# Loss: 0.6674885749816895, solved sudokus 0.0
# Iteration 825
# Loss: 0.6291542649269104, solved sudokus 0.0
# Iteration 830
# Loss: 0.6518369317054749, solved sudokus 0.0
# Iteration 835
# Loss: 0.6264218688011169, solved sudokus 0.0
# Iteration 840
# Loss: 0.6101738214492798, solved sudokus 0.0
# Iteration 845
# Loss: 0.6503947973251343, solved sudokus 0.0
# Iteration 850
# Loss: 0.5996584892272949, solved sudokus 0.0
# Iteration 855
# Loss: 0.6144326329231262, solved sudokus 0.0625
# Iteration 860
# Loss: 0.6222949028015137, solved sudokus 0.0625
# Iteration 865
# Loss: 0.5880495309829712, solved sudokus 0.0625
# Iteration 870
# Loss: 0.6580800414085388, solved sudokus 0.0
# Iteration 875
# Loss: 0.5684899687767029, solved sudokus 0.0
# Iteration 880
# Loss: 0.587790310382843, solved sudokus 0.0
# Iteration 885
# Loss: 0.5450863838195801, solved sudokus 0.0625
# Iteration 890
# Loss: 0.6065115928649902, solved sudokus 0.0
# Iteration 895
# Loss: 0.5983681678771973, solved sudokus 0.0625
# Iteration 900
# Loss: 0.5788533091545105, solved sudokus 0.125
# Iteration 905
# Loss: 0.5735050439834595, solved sudokus 0.0
# Iteration 910
# Loss: 0.6009792685508728, solved sudokus 0.0
# Iteration 915
# Loss: 0.5400123000144958, solved sudokus 0.0
# Iteration 920
# Loss: 0.562612771987915, solved sudokus 0.125
# Iteration 925
# Loss: 0.5445845723152161, solved sudokus 0.0625
# Iteration 930
# Loss: 0.5232625603675842, solved sudokus 0.0625
# Iteration 935
# Loss: 0.55058354139328, solved sudokus 0.0625
# Iteration 940
# Loss: 0.5183184742927551, solved sudokus 0.125
# Iteration 945
# Loss: 0.5277236700057983, solved sudokus 0.0625
# Iteration 950
# Loss: 0.530630886554718, solved sudokus 0.0
# Iteration 955
# Loss: 0.5285005569458008, solved sudokus 0.125
# Iteration 960
# Loss: 0.5391750931739807, solved sudokus 0.125
# Iteration 965
# Loss: 0.5437008142471313, solved sudokus 0.0625
# Iteration 970
# Loss: 0.5039843320846558, solved sudokus 0.0625
# Iteration 975
# Loss: 0.51841801404953, solved sudokus 0.0625
# Iteration 980
# Loss: 0.5266904830932617, solved sudokus 0.1875
# Iteration 985
# Loss: 0.5207642316818237, solved sudokus 0.0625
# Iteration 990
# Loss: 0.5010047554969788, solved sudokus 0.125
# Iteration 995
# Loss: 0.4845351576805115, solved sudokus 0.0625
# Iteration 1000
# Loss: 0.5059298276901245, solved sudokus 0.0
# Iteration 1005
# Loss: 0.48791080713272095, solved sudokus 0.0625
# Iteration 1010
# Loss: 0.5372406244277954, solved sudokus 0.0625
# Iteration 1015
# Loss: 0.48274102807044983, solved sudokus 0.0625
# Iteration 1020
# Loss: 0.46782299876213074, solved sudokus 0.0625
# Iteration 1025
# Loss: 0.4717964231967926, solved sudokus 0.0625
# Iteration 1030
# Loss: 0.4630475640296936, solved sudokus 0.125
# Iteration 1035
# Loss: 0.4965912699699402, solved sudokus 0.25
# Iteration 1040
# Loss: 0.4881040155887604, solved sudokus 0.25
# Iteration 1045
# Loss: 0.4798077642917633, solved sudokus 0.3125
# Iteration 1050
# Loss: 0.47707152366638184, solved sudokus 0.125
# Iteration 1055
# Loss: 0.48035314679145813, solved sudokus 0.1875
# Iteration 1060
# Loss: 0.46849536895751953, solved sudokus 0.0625
# Iteration 1065
# Loss: 0.4362742304801941, solved sudokus 0.125
# Iteration 1070
# Loss: 0.47603583335876465, solved sudokus 0.0625
# Iteration 1075
# Loss: 0.4652792811393738, solved sudokus 0.0625
# Iteration 1080
# Loss: 0.4500594735145569, solved sudokus 0.125
# Iteration 1085
# Loss: 0.45207148790359497, solved sudokus 0.25
# Iteration 1090
# Loss: 0.41570398211479187, solved sudokus 0.3125
# Iteration 1095
# Loss: 0.4417572021484375, solved sudokus 0.3125
# Iteration 1100
# Loss: 0.4713272452354431, solved sudokus 0.3125
# Iteration 1105
# Loss: 0.462737113237381, solved sudokus 0.1875
# Iteration 1110
# Loss: 0.44799456000328064, solved sudokus 0.25
# Iteration 1115
# Loss: 0.4534737169742584, solved sudokus 0.1875
# Iteration 1120
# Loss: 0.4850859045982361, solved sudokus 0.1875
# Iteration 1125
# Loss: 0.42235007882118225, solved sudokus 0.3125
# Epoch 2
# Iteration 1130
# Loss: 0.41996297240257263, solved sudokus 0.3125
# Iteration 1135
# Loss: 0.47405004501342773, solved sudokus 0.375
# Iteration 1140
# Loss: 0.4272926449775696, solved sudokus 0.375
# Iteration 1145
# Loss: 0.4320746958255768, solved sudokus 0.3125
# Iteration 1150
# Loss: 0.4314172863960266, solved sudokus 0.25
# Iteration 1155
# Loss: 0.436055451631546, solved sudokus 0.3125
# Iteration 1160
# Loss: 0.40018683671951294, solved sudokus 0.25
# Iteration 1165
# Loss: 0.41005828976631165, solved sudokus 0.3125
# Iteration 1170
# Loss: 0.46049052476882935, solved sudokus 0.4375
# Iteration 1175
# Loss: 0.43483975529670715, solved sudokus 0.375
# Iteration 1180
# Loss: 0.42617368698120117, solved sudokus 0.3125
# Iteration 1185
# Loss: 0.3840702474117279, solved sudokus 0.25
# Iteration 1190
# Loss: 0.4159816801548004, solved sudokus 0.25
# Iteration 1195
# Loss: 0.4236610531806946, solved sudokus 0.3125
# Iteration 1200
# Loss: 0.44464802742004395, solved sudokus 0.125
# Iteration 1205
# Loss: 0.6887418627738953, solved sudokus 0.0
# Iteration 1210
# Loss: 0.6710826754570007, solved sudokus 0.0
# Iteration 1215
# Loss: 0.5784422755241394, solved sudokus 0.0625
# Iteration 1220
# Loss: 0.5395398736000061, solved sudokus 0.0
# Iteration 1225
# Loss: 0.49307891726493835, solved sudokus 0.0
# Iteration 1230
# Loss: 0.4735347330570221, solved sudokus 0.0
# Iteration 1235
# Loss: 0.4654143452644348, solved sudokus 0.0625
# Iteration 1240
# Loss: 0.4488707482814789, solved sudokus 0.125
# Iteration 1245
# Loss: 0.42203372716903687, solved sudokus 0.1875
# Iteration 1250
# Loss: 0.4138033092021942, solved sudokus 0.3125
# Iteration 1255
# Loss: 0.42261770367622375, solved sudokus 0.1875
# Iteration 1260
# Loss: 0.41813749074935913, solved sudokus 0.1875
# Iteration 1265
# Loss: 0.41271117329597473, solved sudokus 0.3125
# Iteration 1270
# Loss: 0.44085559248924255, solved sudokus 0.25
# Iteration 1275
# Loss: 0.401833713054657, solved sudokus 0.3125
# Iteration 1280
# Loss: 0.42784222960472107, solved sudokus 0.3125
# Iteration 1285
# Loss: 0.41338351368904114, solved sudokus 0.3125
# Iteration 1290
# Loss: 0.4218878149986267, solved sudokus 0.375
# Iteration 1295
# Loss: 0.3860336244106293, solved sudokus 0.25
# Iteration 1300
# Loss: 0.4480409324169159, solved sudokus 0.375
# Iteration 1305
# Loss: 0.3841058313846588, solved sudokus 0.375
# Iteration 1310
# Loss: 0.38884854316711426, solved sudokus 0.4375
# Iteration 1315
# Loss: 0.39420294761657715, solved sudokus 0.4375
# Iteration 1320
# Loss: 0.41890138387680054, solved sudokus 0.4375
# Iteration 1325
# Loss: 0.3792354464530945, solved sudokus 0.4375
# Iteration 1330
# Loss: 0.3774249255657196, solved sudokus 0.4375
# Iteration 1335
# Loss: 0.38234421610832214, solved sudokus 0.4375
# Iteration 1340
# Loss: 0.37521424889564514, solved sudokus 0.4375
# Iteration 1345
# Loss: 0.43554452061653137, solved sudokus 0.5
# Iteration 1350
# Loss: 0.3778848350048065, solved sudokus 0.3125
# Iteration 1355
# Loss: 0.3782198131084442, solved sudokus 0.3125
# Iteration 1360
# Loss: 0.354997843503952, solved sudokus 0.375
# Iteration 1365
# Loss: 0.39553290605545044, solved sudokus 0.3125
# Iteration 1370
# Loss: 0.38675883412361145, solved sudokus 0.25
# Iteration 1375
# Loss: 0.38188618421554565, solved sudokus 0.3125
# Iteration 1380
# Loss: 0.3764823377132416, solved sudokus 0.375
# Iteration 1385
# Loss: 0.36061787605285645, solved sudokus 0.3125
# Iteration 1390
# Loss: 0.3569207191467285, solved sudokus 0.375
# Iteration 1395
# Loss: 0.3648456037044525, solved sudokus 0.3125
# Iteration 1400
# Loss: 0.38461777567863464, solved sudokus 0.3125
# Iteration 1405
# Loss: 0.36262938380241394, solved sudokus 0.375
# Iteration 1410
# Loss: 0.3592641055583954, solved sudokus 0.375
# Iteration 1415
# Loss: 0.3599291145801544, solved sudokus 0.375
# Iteration 1420
# Loss: 0.3604842722415924, solved sudokus 0.375
# Iteration 1425
# Loss: 0.36330273747444153, solved sudokus 0.4375
# Iteration 1430
# Loss: 0.35254529118537903, solved sudokus 0.375
# Iteration 1435
# Loss: 0.3419068455696106, solved sudokus 0.4375
# Iteration 1440
# Loss: 0.3484721779823303, solved sudokus 0.5
# Iteration 1445
# Loss: 0.3702196180820465, solved sudokus 0.5625
# Iteration 1450
# Loss: 0.3786340653896332, solved sudokus 0.375
# Iteration 1455
# Loss: 0.3536699712276459, solved sudokus 0.4375
# Iteration 1460
# Loss: 0.3444490432739258, solved sudokus 0.4375
# Iteration 1465
# Loss: 0.35730239748954773, solved sudokus 0.4375
# Iteration 1470
# Loss: 0.34219101071357727, solved sudokus 0.375
# Iteration 1475
# Loss: 0.33267730474472046, solved sudokus 0.5
# Iteration 1480
# Loss: 0.34497371315956116, solved sudokus 0.4375
# Iteration 1485
# Loss: 0.3521210551261902, solved sudokus 0.4375
# Iteration 1490
# Loss: 0.3613009452819824, solved sudokus 0.5
# Iteration 1495
# Loss: 0.35524559020996094, solved sudokus 0.5
# Iteration 1500
# Loss: 0.3724270164966583, solved sudokus 0.5625
# Iteration 1505
# Loss: 0.3325935900211334, solved sudokus 0.4375
# Iteration 1510
# Loss: 0.3430592715740204, solved sudokus 0.5
# Iteration 1515
# Loss: 0.34383901953697205, solved sudokus 0.5
# Iteration 1520
# Loss: 0.3700311481952667, solved sudokus 0.5
# Iteration 1525
# Loss: 0.3609530031681061, solved sudokus 0.5
# Iteration 1530
# Loss: 0.3314180374145508, solved sudokus 0.5625
# Iteration 1535
# Loss: 0.35223427414894104, solved sudokus 0.5
# Iteration 1540
# Loss: 0.3419823944568634, solved sudokus 0.625
# Iteration 1545
# Loss: 0.35213956236839294, solved sudokus 0.5625
# Iteration 1550
# Loss: 0.343620628118515, solved sudokus 0.5625
# Iteration 1555
# Loss: 0.3417305052280426, solved sudokus 0.5625
# Iteration 1560
# Loss: 0.37099024653434753, solved sudokus 0.5625
# Iteration 1565
# Loss: 0.36980608105659485, solved sudokus 0.625
# Iteration 1570
# Loss: 0.340177059173584, solved sudokus 0.5625
# Iteration 1575
# Loss: 0.3369870185852051, solved sudokus 0.6875
# Iteration 1580
# Loss: 0.33992454409599304, solved sudokus 0.625
# Iteration 1585
# Loss: 0.34386247396469116, solved sudokus 0.5625
# Iteration 1590
# Loss: 0.35665515065193176, solved sudokus 0.5
# Iteration 1595
# Loss: 0.3615431487560272, solved sudokus 0.625
# Iteration 1600
# Loss: 0.33778077363967896, solved sudokus 0.625
# Iteration 1605
# Loss: 0.3346593976020813, solved sudokus 0.625
# Iteration 1610
# Loss: 0.3424583971500397, solved sudokus 0.625
# Iteration 1615
# Loss: 0.3305559754371643, solved sudokus 0.625
# Iteration 1620
# Loss: 0.357433021068573, solved sudokus 0.625
# Iteration 1625
# Loss: 0.3525806963443756, solved sudokus 0.625
# Iteration 1630
# Loss: 0.3389124870300293, solved sudokus 0.5625
# Iteration 1635
# Loss: 0.33922073245048523, solved sudokus 0.5625
# Iteration 1640
# Loss: 0.3336849510669708, solved sudokus 0.625
# Iteration 1645
# Loss: 0.34722504019737244, solved sudokus 0.625
# Iteration 1650
# Loss: 0.338130384683609, solved sudokus 0.625
# Iteration 1655
# Loss: 0.3340865969657898, solved sudokus 0.625
# Iteration 1660
# Loss: 0.3420340418815613, solved sudokus 0.5625
# Iteration 1665
# Loss: 0.331403911113739, solved sudokus 0.5625
# Iteration 1670
# Loss: 0.3321499526500702, solved sudokus 0.625
# Iteration 1675
# Loss: 0.32625341415405273, solved sudokus 0.5625
# Iteration 1680
# Loss: 0.3513410687446594, solved sudokus 0.5625
# Iteration 1685
# Loss: 0.31406038999557495, solved sudokus 0.5625
# Iteration 1690
# Loss: 0.32747748494148254, solved sudokus 0.625
# Epoch 3
# Iteration 1695
# Loss: 0.32430025935173035, solved sudokus 0.625
# Iteration 1700
# Loss: 0.3258337378501892, solved sudokus 0.6875
# Iteration 1705
# Loss: 0.34636130928993225, solved sudokus 0.625
# Iteration 1710
# Loss: 0.32083192467689514, solved sudokus 0.625
# Iteration 1715
# Loss: 0.3086716830730438, solved sudokus 0.5625
# Iteration 1720
# Loss: 0.3240508735179901, solved sudokus 0.625
# Iteration 1725
# Loss: 0.33744916319847107, solved sudokus 0.625
# Iteration 1730
# Loss: 0.31654828786849976, solved sudokus 0.625
# Iteration 1735
# Loss: 0.36022621393203735, solved sudokus 0.625
# Iteration 1740
# Loss: 0.34522467851638794, solved sudokus 0.625
# Iteration 1745
# Loss: 0.3449702858924866, solved sudokus 0.625
# Iteration 1750
# Loss: 0.31585246324539185, solved sudokus 0.625
# Iteration 1755
# Loss: 0.3452942371368408, solved sudokus 0.625
# Iteration 1760
# Loss: 0.3179391920566559, solved sudokus 0.625
# Iteration 1765
# Loss: 0.3559001386165619, solved sudokus 0.625
# Iteration 1770
# Loss: 0.30164557695388794, solved sudokus 0.625
# Iteration 1775
# Loss: 0.3284449577331543, solved sudokus 0.625
# Iteration 1780
# Loss: 0.3435419499874115, solved sudokus 0.6875
# Iteration 1785
# Loss: 0.34412842988967896, solved sudokus 0.625
# Iteration 1790
# Loss: 0.32538682222366333, solved sudokus 0.625
# Iteration 1795
# Loss: 0.32367727160453796, solved sudokus 0.6875
# Iteration 1800
# Loss: 0.33023008704185486, solved sudokus 0.6875
# Iteration 1805
# Loss: 0.32878851890563965, solved sudokus 0.625
# Iteration 1810
# Loss: 0.3148128390312195, solved sudokus 0.625
# Iteration 1815
# Loss: 0.3228696286678314, solved sudokus 0.625
# Iteration 1820
# Loss: 0.32416820526123047, solved sudokus 0.625
# Iteration 1825
# Loss: 0.3214500844478607, solved sudokus 0.625
# Iteration 1830
# Loss: 0.31606703996658325, solved sudokus 0.625
# Iteration 1835
# Loss: 0.32918819785118103, solved sudokus 0.625
# Iteration 1840
# Loss: 0.3402137756347656, solved sudokus 0.625
# Iteration 1845
# Loss: 0.327191025018692, solved sudokus 0.625
# Iteration 1850
# Loss: 0.31875601410865784, solved sudokus 0.625
# Iteration 1855
# Loss: 0.31597012281417847, solved sudokus 0.625
# Iteration 1860
# Loss: 0.3000304102897644, solved sudokus 0.6875
# Iteration 1865
# Loss: 0.32652759552001953, solved sudokus 0.6875
# Iteration 1870
# Loss: 0.3344932496547699, solved sudokus 0.625
# Iteration 1875
# Loss: 0.3306061327457428, solved sudokus 0.6875
# Iteration 1880
# Loss: 0.3243098556995392, solved sudokus 0.6875
# Iteration 1885
# Loss: 0.322947233915329, solved sudokus 0.6875
# Iteration 1890
# Loss: 0.31294336915016174, solved sudokus 0.625
# Iteration 1895
# Loss: 0.32577255368232727, solved sudokus 0.625
# Iteration 1900
# Loss: 0.3067115247249603, solved sudokus 0.625
# Iteration 1905
# Loss: 0.32969608902931213, solved sudokus 0.625
# Iteration 1910
# Loss: 0.3093509376049042, solved sudokus 0.625
# Iteration 1915
# Loss: 0.3295855224132538, solved sudokus 0.625
# Iteration 1920
# Loss: 0.309912770986557, solved sudokus 0.6875
# Iteration 1925
# Loss: 0.3131936490535736, solved sudokus 0.5625
# Iteration 1930
# Loss: 0.30985957384109497, solved sudokus 0.625
# Iteration 1935
# Loss: 0.3172331750392914, solved sudokus 0.6875
# Iteration 1940
# Loss: 0.3200245499610901, solved sudokus 0.6875
# Iteration 1945
# Loss: 0.33172205090522766, solved sudokus 0.6875
# Iteration 1950
# Loss: 0.32103630900382996, solved sudokus 0.6875
# Iteration 1955
# Loss: 0.33078616857528687, solved sudokus 0.5625
# Iteration 1960
# Loss: 0.31767162680625916, solved sudokus 0.5625
# Iteration 1965
# Loss: 0.32818320393562317, solved sudokus 0.6875
# Iteration 1970
# Loss: 0.3298123776912689, solved sudokus 0.5625
# Iteration 1975
# Loss: 0.34020283818244934, solved sudokus 0.625
# Iteration 1980
# Loss: 0.31642991304397583, solved sudokus 0.6875
# Iteration 1985
# Loss: 0.3427397608757019, solved sudokus 0.6875
# Iteration 1990
# Loss: 0.31624993681907654, solved sudokus 0.6875
# Iteration 1995
# Loss: 0.33024314045906067, solved sudokus 0.6875
# Iteration 2000
# Loss: 0.31890150904655457, solved sudokus 0.625
# Iteration 2005
# Loss: 0.32212209701538086, solved sudokus 0.625
# Iteration 2010
# Loss: 0.3051779568195343, solved sudokus 0.6875
# Iteration 2015
# Loss: 0.3152685761451721, solved sudokus 0.6875
# Iteration 2020
# Loss: 0.32529768347740173, solved sudokus 0.6875
# Iteration 2025
# Loss: 0.2955762445926666, solved sudokus 0.75
# Iteration 2030
# Loss: 0.32127493619918823, solved sudokus 0.6875
# Iteration 2035
# Loss: 0.3285377621650696, solved sudokus 0.6875
# Iteration 2040
# Loss: 0.30347856879234314, solved sudokus 0.6875
# Iteration 2045
# Loss: 0.3111073970794678, solved sudokus 0.6875
# Iteration 2050
# Loss: 0.3363818824291229, solved sudokus 0.6875
# Iteration 2055
# Loss: 0.317096084356308, solved sudokus 0.6875
# Iteration 2060
# Loss: 0.3092613220214844, solved sudokus 0.75
# Iteration 2065
# Loss: 0.33257028460502625, solved sudokus 0.75
# Iteration 2070
# Loss: 0.3109987676143646, solved sudokus 0.75
# Iteration 2075
# Loss: 0.32942527532577515, solved sudokus 0.625
# Iteration 2080
# Loss: 0.3001706898212433, solved sudokus 0.6875
# Iteration 2085
# Loss: 0.321534126996994, solved sudokus 0.625
# Iteration 2090
# Loss: 0.3112505376338959, solved sudokus 0.625
# Iteration 2095
# Loss: 0.3128843903541565, solved sudokus 0.625
# Iteration 2100
# Loss: 0.30249887704849243, solved sudokus 0.625
# Iteration 2105
# Loss: 0.3046983778476715, solved sudokus 0.625
# Iteration 2110
# Loss: 0.31053051352500916, solved sudokus 0.6875
# Iteration 2115
# Loss: 0.3157460391521454, solved sudokus 0.75
# Iteration 2120
# Loss: 0.31752127408981323, solved sudokus 0.75
# Iteration 2125
# Loss: 0.3137287199497223, solved sudokus 0.625
# Iteration 2130
# Loss: 0.30492281913757324, solved sudokus 0.6875
# Iteration 2135
# Loss: 0.32564643025398254, solved sudokus 0.6875
# Iteration 2140
# Loss: 0.3137344419956207, solved sudokus 0.625
# Iteration 2145
# Loss: 0.3019113540649414, solved sudokus 0.625
# Iteration 2150
# Loss: 0.32076650857925415, solved sudokus 0.6875
# Iteration 2155
# Loss: 0.31538036465644836, solved sudokus 0.6875
# Iteration 2160
# Loss: 0.30938461422920227, solved sudokus 0.6875
# Iteration 2165
# Loss: 0.3068101108074188, solved sudokus 0.625
# Iteration 2170
# Loss: 0.3083745837211609, solved sudokus 0.6875
# Iteration 2175
# Loss: 0.30739641189575195, solved sudokus 0.6875
# Iteration 2180
# Loss: 0.3102356493473053, solved sudokus 0.6875
# Iteration 2185
# Loss: 0.30234494805336, solved sudokus 0.6875
# Iteration 2190
# Loss: 0.3194372355937958, solved sudokus 0.6875
# Iteration 2195
# Loss: 0.2969675660133362, solved sudokus 0.75
# Iteration 2200
# Loss: 0.3050830662250519, solved sudokus 0.75
# Iteration 2205
# Loss: 0.29203006625175476, solved sudokus 0.75
# Iteration 2210
# Loss: 0.3012670576572418, solved sudokus 0.75
# Iteration 2215
# Loss: 0.29853108525276184, solved sudokus 0.75
# Iteration 2220
# Loss: 0.3047715723514557, solved sudokus 0.75
# Iteration 2225
# Loss: 0.29180946946144104, solved sudokus 0.6875
# Iteration 2230
# Loss: 0.3004000782966614, solved sudokus 0.75
# Iteration 2235
# Loss: 0.33255258202552795, solved sudokus 0.6875
# Iteration 2240
# Loss: 0.2968246042728424, solved sudokus 0.75
# Iteration 2245
# Loss: 0.3038504123687744, solved sudokus 0.75
# Iteration 2250
# Loss: 0.29945701360702515, solved sudokus 0.6875
# Epoch 4
# Iteration 2255
# Loss: 0.3189951479434967, solved sudokus 0.6875
# Iteration 2260
# Loss: 0.31101128458976746, solved sudokus 0.75
# Iteration 2265
# Loss: 0.2933730185031891, solved sudokus 0.75
# Iteration 2270
# Loss: 0.29602473974227905, solved sudokus 0.6875
# Iteration 2275
# Loss: 0.3054516315460205, solved sudokus 0.6875
# Iteration 2280
# Loss: 0.2928783595561981, solved sudokus 0.6875
# Iteration 2285
# Loss: 0.3077062666416168, solved sudokus 0.6875
# Iteration 2290
# Loss: 0.29838746786117554, solved sudokus 0.6875
# Iteration 2295
# Loss: 0.28896236419677734, solved sudokus 0.6875
# Iteration 2300
# Loss: 0.3045284152030945, solved sudokus 0.6875
# Iteration 2305
# Loss: 0.31031328439712524, solved sudokus 0.75
# Iteration 2310
# Loss: 0.3038579523563385, solved sudokus 0.6875
# Iteration 2315
# Loss: 0.3218393623828888, solved sudokus 0.6875
# Iteration 2320
# Loss: 0.2767723798751831, solved sudokus 0.6875
# Iteration 2325
# Loss: 0.30541524291038513, solved sudokus 0.6875
# Iteration 2330
# Loss: 0.3058755397796631, solved sudokus 0.6875
# Iteration 2335
# Loss: 0.2851094901561737, solved sudokus 0.625
# Iteration 2340
# Loss: 0.2915939688682556, solved sudokus 0.6875
# Iteration 2345
# Loss: 0.2875062823295593, solved sudokus 0.75
# Iteration 2350
# Loss: 0.3008207380771637, solved sudokus 0.6875
# Iteration 2355
# Loss: 0.310183048248291, solved sudokus 0.6875
# Iteration 2360
# Loss: 0.28855961561203003, solved sudokus 0.75
# Iteration 2365
# Loss: 0.30026111006736755, solved sudokus 0.6875
# Iteration 2370
# Loss: 0.3208785057067871, solved sudokus 0.6875
# Iteration 2375
# Loss: 0.30681654810905457, solved sudokus 0.6875
# Iteration 2380
# Loss: 0.29506969451904297, solved sudokus 0.625
# Iteration 2385
# Loss: 0.29559090733528137, solved sudokus 0.6875
# Iteration 2390
# Loss: 0.29246020317077637, solved sudokus 0.625
# Iteration 2395
# Loss: 0.29590633511543274, solved sudokus 0.625
# Iteration 2400
# Loss: 0.29912233352661133, solved sudokus 0.6875
# Iteration 2405
# Loss: 0.28983721137046814, solved sudokus 0.75
# Iteration 2410
# Loss: 0.3135696351528168, solved sudokus 0.75
# Iteration 2415
# Loss: 0.30931705236434937, solved sudokus 0.75
# Iteration 2420
# Loss: 0.32105234265327454, solved sudokus 0.75
# Iteration 2425
# Loss: 0.3106693923473358, solved sudokus 0.75
# Iteration 2430
# Loss: 0.2933121621608734, solved sudokus 0.75
# Iteration 2435
# Loss: 0.30824729800224304, solved sudokus 0.75
# Iteration 2440
# Loss: 0.3071286082267761, solved sudokus 0.75
# Iteration 2445
# Loss: 0.2816798686981201, solved sudokus 0.8125
# Iteration 2450
# Loss: 0.3263978064060211, solved sudokus 0.75
# Iteration 2455
# Loss: 0.28949490189552307, solved sudokus 0.625
# Iteration 2460
# Loss: 0.30718353390693665, solved sudokus 0.6875
# Iteration 2465
# Loss: 0.30530205368995667, solved sudokus 0.625
# Iteration 2470
# Loss: 0.29414287209510803, solved sudokus 0.75
# Iteration 2475
# Loss: 0.3002258241176605, solved sudokus 0.75
# Iteration 2480
# Loss: 0.31352537870407104, solved sudokus 0.75
# Iteration 2485
# Loss: 0.3163399398326874, solved sudokus 0.75
# Iteration 2490
# Loss: 0.2935471534729004, solved sudokus 0.75
# Iteration 2495
# Loss: 0.3078438639640808, solved sudokus 0.75
# Iteration 2500
# Loss: 0.305244117975235, solved sudokus 0.75
# Iteration 2505
# Loss: 0.29436585307121277, solved sudokus 0.75
# Iteration 2510
# Loss: 0.29405879974365234, solved sudokus 0.75
# Iteration 2515
# Loss: 0.307662695646286, solved sudokus 0.8125
# Iteration 2520
# Loss: 0.2944318950176239, solved sudokus 0.8125
# Iteration 2525
# Loss: 0.2808886766433716, solved sudokus 0.875
# Iteration 2530
# Loss: 0.32308831810951233, solved sudokus 0.75
# Iteration 2535
# Loss: 0.2857789099216461, solved sudokus 0.875
# Iteration 2540
# Loss: 0.2864413857460022, solved sudokus 0.875
# Iteration 2545
# Loss: 0.27105623483657837, solved sudokus 0.8125
# Iteration 2550
# Loss: 0.29338884353637695, solved sudokus 0.8125
# Iteration 2555
# Loss: 0.29890745878219604, solved sudokus 0.8125
# Iteration 2560
# Loss: 0.28934815526008606, solved sudokus 0.6875
# Iteration 2565
# Loss: 0.27795371413230896, solved sudokus 0.6875
# Iteration 2570
# Loss: 0.2942086160182953, solved sudokus 0.8125
# Iteration 2575
# Loss: 0.3063961863517761, solved sudokus 0.8125
# Iteration 2580
# Loss: 0.289236843585968, solved sudokus 0.8125
# Iteration 2585
# Loss: 0.2983665466308594, solved sudokus 0.8125
# Iteration 2590
# Loss: 0.29119786620140076, solved sudokus 0.8125
# Iteration 2595
# Loss: 0.2941506505012512, solved sudokus 0.75
# Iteration 2600
# Loss: 0.2945874333381653, solved sudokus 0.75
# Iteration 2605
# Loss: 0.2861969470977783, solved sudokus 0.8125
# Iteration 2610
# Loss: 0.28427359461784363, solved sudokus 0.8125
# Iteration 2615
# Loss: 0.29473093152046204, solved sudokus 0.8125
# Iteration 2620
# Loss: 0.3061043918132782, solved sudokus 0.8125
# Iteration 2625
# Loss: 0.2812994122505188, solved sudokus 0.75
# Iteration 2630
# Loss: 0.2864437699317932, solved sudokus 0.75
# Iteration 2635
# Loss: 0.31373926997184753, solved sudokus 0.75
# Iteration 2640
# Loss: 0.28808659315109253, solved sudokus 0.75
# Iteration 2645
# Loss: 0.3019804358482361, solved sudokus 0.8125
# Iteration 2650
# Loss: 0.2933082580566406, solved sudokus 0.6875
# Iteration 2655
# Loss: 0.2890360355377197, solved sudokus 0.8125
# Iteration 2660
# Loss: 0.29971593618392944, solved sudokus 0.75
# Iteration 2665
# Loss: 0.293758362531662, solved sudokus 0.8125
# Iteration 2670
# Loss: 0.2975688874721527, solved sudokus 0.8125
# Iteration 2675
# Loss: 0.30239424109458923, solved sudokus 0.875
# Iteration 2680
# Loss: 0.3136068880558014, solved sudokus 0.75
# Iteration 2685
# Loss: 0.28445830941200256, solved sudokus 0.8125
# Iteration 2690
# Loss: 0.28414931893348694, solved sudokus 0.75
# Iteration 2695
# Loss: 0.289042204618454, solved sudokus 0.75
# Iteration 2700
# Loss: 0.2773774564266205, solved sudokus 0.8125
# Iteration 2705
# Loss: 0.2907137870788574, solved sudokus 0.8125
# Iteration 2710
# Loss: 0.2860543131828308, solved sudokus 0.8125
# Iteration 2715
# Loss: 0.2881520092487335, solved sudokus 0.8125
# Iteration 2720
# Loss: 0.27447283267974854, solved sudokus 0.8125
# Iteration 2725
# Loss: 0.29021212458610535, solved sudokus 0.8125
# Iteration 2730
# Loss: 0.28569892048835754, solved sudokus 0.8125
# Iteration 2735
# Loss: 0.28796228766441345, solved sudokus 0.75
# Iteration 2740
# Loss: 0.2960587441921234, solved sudokus 0.75
# Iteration 2745
# Loss: 0.3003309667110443, solved sudokus 0.75
# Iteration 2750
# Loss: 0.29169467091560364, solved sudokus 0.75
# Iteration 2755
# Loss: 0.2897645831108093, solved sudokus 0.875
# Iteration 2760
# Loss: 0.3058900535106659, solved sudokus 0.875
# Iteration 2765
# Loss: 0.2993071675300598, solved sudokus 0.8125
# Iteration 2770
# Loss: 0.27987661957740784, solved sudokus 0.875
# Iteration 2775
# Loss: 0.2776765525341034, solved sudokus 0.8125
# Iteration 2780
# Loss: 0.28188377618789673, solved sudokus 0.875
# Iteration 2785
# Loss: 0.3138798177242279, solved sudokus 0.8125
# Iteration 2790
# Loss: 0.291480153799057, solved sudokus 0.8125
# Iteration 2795
# Loss: 0.28232839703559875, solved sudokus 0.8125
# Iteration 2800
# Loss: 0.30701759457588196, solved sudokus 0.9375
# Iteration 2805
# Loss: 0.29291826486587524, solved sudokus 0.875
# Iteration 2810
# Loss: 0.2919204831123352, solved sudokus 0.8125
# Iteration 2815
# Loss: 0.2911047339439392, solved sudokus 0.6875
# Epoch 5
# Iteration 2820
# Loss: 0.2964499294757843, solved sudokus 0.8125
# Iteration 2825
# Loss: 0.29560357332229614, solved sudokus 0.8125
# Iteration 2830
# Loss: 0.29642319679260254, solved sudokus 0.8125
# Iteration 2835
# Loss: 0.291032612323761, solved sudokus 0.75
# Iteration 2840
# Loss: 0.29672425985336304, solved sudokus 0.75
# Iteration 2845
# Loss: 0.3058943748474121, solved sudokus 0.8125
# Iteration 2850
# Loss: 0.2951987385749817, solved sudokus 0.8125
# Iteration 2855
# Loss: 0.30353444814682007, solved sudokus 0.75
# Iteration 2860
# Loss: 0.28800061345100403, solved sudokus 0.75
# Iteration 2865
# Loss: 0.28119781613349915, solved sudokus 0.75
# Iteration 2870
# Loss: 0.2911924719810486, solved sudokus 0.75
# Iteration 2875
# Loss: 0.276500940322876, solved sudokus 0.75
# Iteration 2880
# Loss: 0.29747912287712097, solved sudokus 0.75
# Iteration 2885
# Loss: 0.2870844006538391, solved sudokus 0.875
# Iteration 2890
# Loss: 0.29047849774360657, solved sudokus 0.75
# Iteration 2895
# Loss: 0.29394227266311646, solved sudokus 0.875
# Iteration 2900
# Loss: 0.2956879138946533, solved sudokus 0.8125
# Iteration 2905
# Loss: 0.2976793348789215, solved sudokus 0.75
# Iteration 2910
# Loss: 0.2883010804653168, solved sudokus 0.75
# Iteration 2915
# Loss: 0.29639503359794617, solved sudokus 0.75
# Iteration 2920
# Loss: 0.2791956961154938, solved sudokus 0.75
# Iteration 2925
# Loss: 0.2875187397003174, solved sudokus 0.75
# Iteration 2930
# Loss: 0.28851574659347534, solved sudokus 0.8125
# Iteration 2935
# Loss: 0.30462366342544556, solved sudokus 0.8125
# Iteration 2940
# Loss: 0.27927419543266296, solved sudokus 0.8125
# Iteration 2945
# Loss: 0.2869410812854767, solved sudokus 0.875
# Iteration 2950
# Loss: 0.28618893027305603, solved sudokus 0.8125
# Iteration 2955
# Loss: 0.27792438864707947, solved sudokus 0.8125
# Iteration 2960
# Loss: 0.29587727785110474, solved sudokus 0.875
# Iteration 2965
# Loss: 0.28958210349082947, solved sudokus 0.875
# Iteration 2970
# Loss: 0.28735071420669556, solved sudokus 0.8125
# Iteration 2975
# Loss: 0.27385058999061584, solved sudokus 0.8125
# Iteration 2980
# Loss: 0.26866525411605835, solved sudokus 0.8125
# Iteration 2985
# Loss: 0.2914262115955353, solved sudokus 0.875
# Iteration 2990
# Loss: 0.312107652425766, solved sudokus 0.8125
# Iteration 2995
# Loss: 0.27622270584106445, solved sudokus 0.8125
# Iteration 3000
# Loss: 0.27974992990493774, solved sudokus 0.75
# Iteration 3005
# Loss: 0.29940611124038696, solved sudokus 0.8125
# Iteration 3010
# Loss: 0.3012261390686035, solved sudokus 0.875
# Iteration 3015
# Loss: 0.2759515643119812, solved sudokus 0.875
# Iteration 3020
# Loss: 0.2967027723789215, solved sudokus 0.75
# Iteration 3025
# Loss: 0.2816474139690399, solved sudokus 0.875
# Iteration 3030
# Loss: 0.29567453265190125, solved sudokus 0.875
# Iteration 3035
# Loss: 0.29658856987953186, solved sudokus 0.8125
# Iteration 3040
# Loss: 0.285613477230072, solved sudokus 0.75
# Iteration 3045
# Loss: 0.28173941373825073, solved sudokus 0.8125
# Iteration 3050
# Loss: 0.2713252902030945, solved sudokus 0.75
# Iteration 3055
# Loss: 0.29940369725227356, solved sudokus 0.875
# Iteration 3060
# Loss: 0.2920324206352234, solved sudokus 0.875
# Iteration 3065
# Loss: 0.2849692404270172, solved sudokus 0.8125
# Iteration 3070
# Loss: 0.2778635323047638, solved sudokus 0.8125
# Iteration 3075
# Loss: 0.28530260920524597, solved sudokus 0.75
# Iteration 3080
# Loss: 0.27433714270591736, solved sudokus 0.9375
# Iteration 3085
# Loss: 0.2920551300048828, solved sudokus 0.9375
# Iteration 3090
# Loss: 0.31596583127975464, solved sudokus 0.9375
# Iteration 3095
# Loss: 0.27557966113090515, solved sudokus 0.875
# Iteration 3100
# Loss: 0.2973465621471405, solved sudokus 0.9375
# Iteration 3105
# Loss: 0.28119802474975586, solved sudokus 0.875
# Iteration 3110
# Loss: 0.2912907004356384, solved sudokus 0.8125
# Iteration 3115
# Loss: 0.2862277328968048, solved sudokus 0.875
# Iteration 3120
# Loss: 0.28728336095809937, solved sudokus 0.875
# Iteration 3125
# Loss: 0.2995813488960266, solved sudokus 0.8125
# Iteration 3130
# Loss: 0.2792799770832062, solved sudokus 0.9375
# Iteration 3135
# Loss: 0.29436513781547546, solved sudokus 0.875
# Iteration 3140
# Loss: 0.28288930654525757, solved sudokus 0.8125
# Iteration 3145
# Loss: 0.2810491919517517, solved sudokus 0.8125
# Iteration 3150
# Loss: 0.28173312544822693, solved sudokus 0.875
# Iteration 3155
# Loss: 0.2850843071937561, solved sudokus 0.8125
# Iteration 3160
# Loss: 0.2788246273994446, solved sudokus 0.8125
# Iteration 3165
# Loss: 0.30243903398513794, solved sudokus 0.875
# Iteration 3170
# Loss: 0.281977117061615, solved sudokus 0.875
# Iteration 3175
# Loss: 0.2904776930809021, solved sudokus 0.8125
# Iteration 3180
# Loss: 0.31442418694496155, solved sudokus 0.875
# Iteration 3185
# Loss: 0.2673753798007965, solved sudokus 0.8125
# Iteration 3190
# Loss: 0.27234166860580444, solved sudokus 0.8125
# Iteration 3195
# Loss: 0.27561038732528687, solved sudokus 0.8125
# Iteration 3200
# Loss: 0.27177882194519043, solved sudokus 0.8125
# Iteration 3205
# Loss: 0.2896367609500885, solved sudokus 0.75
# Iteration 3210
# Loss: 0.27600324153900146, solved sudokus 0.8125
# Iteration 3215
# Loss: 0.2864181399345398, solved sudokus 0.8125
# Iteration 3220
# Loss: 0.2744583785533905, solved sudokus 0.8125
# Iteration 3225
# Loss: 0.27690547704696655, solved sudokus 0.8125
# Iteration 3230
# Loss: 0.2933208644390106, solved sudokus 0.875
# Iteration 3235
# Loss: 0.2760644853115082, solved sudokus 0.8125
# Iteration 3240
# Loss: 0.3031097948551178, solved sudokus 0.875
# Iteration 3245
# Loss: 0.28314337134361267, solved sudokus 0.9375
# Iteration 3250
# Loss: 0.2859102785587311, solved sudokus 0.8125
# Iteration 3255
# Loss: 0.2854004502296448, solved sudokus 0.75
# Iteration 3260
# Loss: 0.2815527319908142, solved sudokus 0.8125
# Iteration 3265
# Loss: 0.29543644189834595, solved sudokus 0.8125
# Iteration 3270
# Loss: 0.29735544323921204, solved sudokus 0.875
# Iteration 3275
# Loss: 0.28848299384117126, solved sudokus 0.8125
# Iteration 3280
# Loss: 0.27675268054008484, solved sudokus 0.8125
# Iteration 3285
# Loss: 0.28815969824790955, solved sudokus 0.8125
# Iteration 3290
# Loss: 0.28345009684562683, solved sudokus 0.875
# Iteration 3295
# Loss: 0.2735801637172699, solved sudokus 0.875
# Iteration 3300
# Loss: 0.29023393988609314, solved sudokus 0.8125
# Iteration 3305
# Loss: 0.27104130387306213, solved sudokus 0.9375
# Iteration 3310
# Loss: 0.27679234743118286, solved sudokus 0.8125
# Iteration 3315
# Loss: 0.29981729388237, solved sudokus 0.9375
# Iteration 3320
# Loss: 0.28309670090675354, solved sudokus 0.9375
# Iteration 3325
# Loss: 0.28129225969314575, solved sudokus 0.9375
# Iteration 3330
# Loss: 0.27698078751564026, solved sudokus 0.9375
# Iteration 3335
# Loss: 0.29120394587516785, solved sudokus 0.875
# Iteration 3340
# Loss: 0.2859261631965637, solved sudokus 0.9375
# Iteration 3345
# Loss: 0.2830958962440491, solved sudokus 0.9375
# Iteration 3350
# Loss: 0.2736629843711853, solved sudokus 0.9375
# Iteration 3355
# Loss: 0.2685225009918213, solved sudokus 0.9375
# Iteration 3360
# Loss: 0.28784409165382385, solved sudokus 0.875
# Iteration 3365
# Loss: 0.27385610342025757, solved sudokus 0.9375
# Iteration 3370
# Loss: 0.2753300368785858, solved sudokus 0.875
# Iteration 3375
# Loss: 0.29883450269699097, solved sudokus 0.875
# Epoch 6
# Iteration 3380
# Loss: 0.28757333755493164, solved sudokus 0.9375
# Iteration 3385
# Loss: 0.2761066257953644, solved sudokus 0.9375
# Iteration 3390
# Loss: 0.2709450423717499, solved sudokus 0.9375
# Iteration 3395
# Loss: 0.28586477041244507, solved sudokus 0.875
# Iteration 3400
# Loss: 0.26923635601997375, solved sudokus 0.875
# Iteration 3405
# Loss: 0.2860155701637268, solved sudokus 0.8125
# Iteration 3410
# Loss: 0.2729446291923523, solved sudokus 0.875
# Iteration 3415
# Loss: 0.2854500412940979, solved sudokus 0.875
# Iteration 3420
# Loss: 0.2868227958679199, solved sudokus 0.875
# Iteration 3425
# Loss: 0.2843979299068451, solved sudokus 0.875
# Iteration 3430
# Loss: 0.2950095236301422, solved sudokus 0.75
# Iteration 3435
# Loss: 0.2705254554748535, solved sudokus 0.8125
# Iteration 3440
# Loss: 0.29364562034606934, solved sudokus 0.8125
# Iteration 3445
# Loss: 0.2989010810852051, solved sudokus 0.875
# Iteration 3450
# Loss: 0.27938881516456604, solved sudokus 0.875
# Iteration 3455
# Loss: 0.25866323709487915, solved sudokus 0.8125
# Iteration 3460
# Loss: 0.30258527398109436, solved sudokus 0.875
# Iteration 3465
# Loss: 0.3184255063533783, solved sudokus 0.9375
# Iteration 3470
# Loss: 0.29706692695617676, solved sudokus 0.9375
# Iteration 3475
# Loss: 0.2855324447154999, solved sudokus 0.75
# Iteration 3480
# Loss: 0.28958314657211304, solved sudokus 1.0
# Iteration 3485
# Loss: 0.2712940275669098, solved sudokus 0.9375
# Iteration 3490
# Loss: 0.2806616425514221, solved sudokus 0.8125
# Iteration 3495
# Loss: 0.28335505723953247, solved sudokus 0.8125
# Iteration 3500
# Loss: 0.2729009687900543, solved sudokus 0.9375
# Iteration 3505
# Loss: 0.2843380868434906, solved sudokus 0.875
# Iteration 3510
# Loss: 0.2835124135017395, solved sudokus 0.875
# Iteration 3515
# Loss: 0.2926226556301117, solved sudokus 0.875
# Iteration 3520
# Loss: 0.26986879110336304, solved sudokus 0.8125
# Iteration 3525
# Loss: 0.27672773599624634, solved sudokus 0.9375
# Iteration 3530
# Loss: 0.28566956520080566, solved sudokus 0.9375
# Iteration 3535
# Loss: 0.271745890378952, solved sudokus 1.0
# Iteration 3540
# Loss: 0.2838493883609772, solved sudokus 1.0
# Iteration 3545
# Loss: 0.280971884727478, solved sudokus 1.0
# Iteration 3550
# Loss: 0.2733191251754761, solved sudokus 1.0
# Iteration 3555
# Loss: 0.2684040367603302, solved sudokus 0.9375
# Iteration 3560
# Loss: 0.27494850754737854, solved sudokus 0.9375
# Iteration 3565
# Loss: 0.2688523828983307, solved sudokus 0.8125
# Iteration 3570
# Loss: 0.26895442605018616, solved sudokus 0.875
# Iteration 3575
# Loss: 0.28197962045669556, solved sudokus 0.8125
# Iteration 3580
# Loss: 0.2777918875217438, solved sudokus 0.8125
# Iteration 3585
# Loss: 0.2694418728351593, solved sudokus 0.9375
# Iteration 3590
# Loss: 0.2723938822746277, solved sudokus 1.0
# Iteration 3595
# Loss: 0.2693003714084625, solved sudokus 0.875
# Iteration 3600
# Loss: 0.28590455651283264, solved sudokus 0.8125
# Iteration 3605
# Loss: 0.2811950743198395, solved sudokus 0.8125
# Iteration 3610
# Loss: 0.3130551874637604, solved sudokus 0.875
# Iteration 3615
# Loss: 0.286144882440567, solved sudokus 0.8125
# Iteration 3620
# Loss: 0.288327693939209, solved sudokus 0.875
# Iteration 3625
# Loss: 0.2858148217201233, solved sudokus 0.8125
# Iteration 3630
# Loss: 0.2691749036312103, solved sudokus 0.875
# Iteration 3635
# Loss: 0.27973654866218567, solved sudokus 0.875
# Iteration 3640
# Loss: 0.2768683433532715, solved sudokus 0.875
# Iteration 3645
# Loss: 0.2855764925479889, solved sudokus 0.9375
# Iteration 3650
# Loss: 0.2750977873802185, solved sudokus 0.9375
# Iteration 3655
# Loss: 0.2739318907260895, solved sudokus 0.9375
# Iteration 3660
# Loss: 0.2968783378601074, solved sudokus 0.9375
# Iteration 3665
# Loss: 0.274981290102005, solved sudokus 0.875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-5d9b89eaad11> in <module>
#      19 #             print("src_ids.size()", src_ids.size())
#      20 #             print("dst_ids.size()", dst_ids.size())
# ---> 21             outputs = gnn(inputs, src_ids, dst_ids)
#      22 #             print("outputs[i,:,:].size()", outputs[0,:,:].size())
#      23 #             print("outputs[i,:,:].dtype", outputs[0,:,:].dtype)
#
# ~\anaconda3\envs\dle\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-21-8c941b1af7b9> in forward(self, node_inputs, src_ids, dst_ids)
#      55 #             print("msg_net_inputs.size()", msg_net_inputs.size())
#      56
# ---> 57             messages_edges = self.msg_net(msg_net_inputs) # shape [n_edges, n_edge_features]=[1620,11]
#      58
#      59 #             print("messages.size():", messages.size())
#
# ~\anaconda3\envs\dle\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\anaconda3\envs\dle\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~\anaconda3\envs\dle\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\anaconda3\envs\dle\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~\anaconda3\envs\dle\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
# Save the model to disk (the pth-files will be submitted automatically together with your notebook)
if not skip_training:
    tools.save_model(gnn, '7_gnn.pth')
else:
    gnn = GNN()
    tools.load_model(gnn, '7_gnn.pth', device)
# Out:
# Do you want to save the model (type yes to confirm)? yes
# Model saved to 7_gnn.pth.

# %% [markdown]
# ## Evaluate the trained model

# %%
# Get graph iterations for some test puzzles
with torch.no_grad():
    inputs, targets, src_ids, dst_ids = iter(testloader).next()
    inputs, targets = inputs.to(device), targets.to(device)
    src_ids, dst_ids = src_ids.to(device), dst_ids.to(device)

    batch_size = inputs.size(0) // 81
    outputs = gnn(inputs, src_ids, dst_ids)  # [n_iters, n_nodes, 9]

    solution = outputs.view(gnn.n_iters, batch_size, 9, 9, 9)
    final_solution = solution[-1].argmax(dim=3)
    print('Solved puzzles in the current mini-batch:')
    print((final_solution.view(-1, 81) == targets.view(batch_size, 81)).all(dim=1))
# Out:
# Solved puzzles in the current mini-batch:
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True, False,  True,  True])

# %%
# Visualize graph iteration for one of the puzzles
ix = 0
for i in range(gnn.n_iters):
    tools.draw_sudoku(solution[i, 0], logits=True)

# %%
fraction_solved = fraction_of_solved_puzzles(gnn, testloader)
assert fraction_solved > .93, "Poor accuracy ({:.3f})".format(fraction_solved)
print('Success')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-45-b096864a3590> in <module>
#       1 fraction_solved = fraction_of_solved_puzzles(gnn, testloader)
# ----> 2 assert fraction_solved > .93, "Poor accuracy ({:.3f})".format(fraction_solved)
#       3 print('Success')
#
# AssertionError: Poor accuracy (0.875)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Conclusions</b>
# </div>
#
# In this exercise, we learned how to train a simple graph neural network.
